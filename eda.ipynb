# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("feature_engineered_dataset.csv")

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33638 entries, 0 to 33637
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                33638 non-null  object
#  1   store_id            33638 non-null  object
#  2   product_id          33638 non-null  object
#  3   category            33638 non-null  object
#  4   region              33638 non-null  object
#  5   inventory_level     33638 non-null  int64
#  6   units_sold          33638 non-null  int64
#  7   units_ordered       33638 non-null  int64
#  8   demand_forecast     33638 non-null  float64
#  9   price               33638 non-null  float64
#  10  discount            33638 non-null  int64
#  11  weather_condition   33638 non-null  object
#  12  holiday_promotion   33638 non-null  int64
#  13  competitor_pricing  33638 non-null  float64
#  14  seasonality         33638 non-null  object
#  15  visitors            33638 non-null  int64
#  16  cost                33638 non-null  float64
#  17  profit_margin       33638 non-null  float64
#  18  margin_percent      33638 non-null  float64
#  19  demand_ratio        33638 non-null  float64
#  20  inventory_pressure  33638 non-null  float64
#  21  competitor_gap      33638 non-null  float64
#  22  discounted_price    33638 non-null  float64
#  23  revenue             33638 non-null  float64
#  24  conversion_rate     33638 non-null  float64
#  25  price_demand_ratio  33638 non-null  float64
#  26  stock_remaining     33638 non-null  int64
#  27  traffic_intensity   33638 non-null  float64
#  28  day_of_week         33638 non-null  int64
#  29  month               33638 non-null  int64
#  30  is_weekend          33638 non-null  int64
# dtypes: float64(14), int64(10), object(7)
# memory usage: 8.0+ MB
#        inventory_level    units_sold  units_ordered  demand_forecast  \
# count     33638.000000  33638.000000   33638.000000     33638.000000
# mean        274.974582    137.115405     109.871187       142.140954
# std         129.839197    109.098617      52.353185       109.452942
# min          50.000000      0.000000      20.000000        -9.990000
# 25%         163.000000     49.000000      65.000000        54.202500
# 50%         274.000000    108.000000     110.000000       113.475000
# 75%         388.000000    203.000000     155.000000       208.517500
# max         500.000000    496.000000     200.000000       506.370000
#
#               price      discount  holiday_promotion  competitor_pricing  \
# count  33638.000000  33638.000000       33638.000000        33638.000000
# mean      55.330587      0.802158           0.498722           55.322039
# std       25.979803      0.398378           0.500006           26.137157
# min       10.010000      0.000000           0.000000            5.030000
# 25%       32.982500      1.000000           0.000000           33.002500
# 50%       55.340000      1.000000           0.000000           55.180000
# 75%       78.090000      1.000000           1.000000           78.040000
# max      100.000000      1.000000           1.000000          104.810000
#
#            visitors          cost  ...  competitor_gap  discounted_price  \
# count  33638.000000  33638.000000  ...    33638.000000      33638.000000
# mean     311.272757     35.955137  ...        0.008547         10.942953
# std      129.994770     17.705142  ...        2.895734         24.882332
# min       51.000000      1.000000  ...       -5.000000          0.000000
# 25%      216.000000     21.090000  ...       -2.510000          0.000000
# 50%      298.000000     35.285000  ...        0.030000          0.000000
# 75%      392.000000     49.560000  ...        2.520000          0.000000
# max      785.000000     79.510000  ...        5.000000         99.960000
#
#             revenue  conversion_rate  price_demand_ratio  stock_remaining  \
# count  33638.000000     33638.000000        33638.000000     33638.000000
# mean    1514.727036         0.397383            1.541300       137.859177
# std     4531.920650         0.216668            5.047212       109.440344
# min        0.000000         0.000000            0.020782         0.000000
# 25%        0.000000         0.220183            0.229754        49.000000
# 50%        0.000000         0.397156            0.464284       110.000000
# 75%        0.000000         0.567706            1.080914       205.000000
# max    42879.600000         0.901734           99.870000       499.000000
#
#        traffic_intensity   day_of_week         month    is_weekend
# count       33638.000000  33638.000000  33638.000000  33638.000000
# mean            1.381397      3.002259      6.060289      0.286521
# std             0.827816      2.000028      3.183247      0.452143
# min             0.121849      0.000000      1.000000      0.000000
# 25%             0.853053      1.000000      3.000000      0.000000
# 50%             1.193029      3.000000      6.000000      0.000000
# 75%             1.642553      5.000000      9.000000      1.000000
# max             6.549020      6.000000     12.000000      1.000000
#
# [8 rows x 24 columns]

# %%
df.hist(figsize=(15,10))
plt.show()

# %%
sns.scatterplot(x="price", y="units_sold", data=df)
plt.show()

# %%
sns.scatterplot(x="inventory_level", y="units_sold", data=df)
plt.show()

# %%
sns.scatterplot(x="competitor_pricing", y="price", data=df)
plt.show()

# %%
sns.scatterplot(x="visitors", y="units_sold", data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.barplot(x="category", y="units_sold", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x="region", y="units_sold", data=df)
plt.show()

# %%
sns.boxplot(x="seasonality", y="units_sold", data=df)
plt.show()

# %%
sns.boxplot(x="weather_condition", y="units_sold", data=df)
plt.show()

# %%
sns.barplot(x="holiday_promotion", y="units_sold", data=df)
plt.show()

# %%
sns.scatterplot(x="discount", y="units_sold", data=df)
plt.show()

# %%
sns.histplot(df["revenue"], kde=True)
plt.show()

# %%
sns.histplot(df["profit_margin"], kde=True)
plt.show()

# %%
df["date"] = pd.to_datetime(df["date"])
df.groupby("date")["units_sold"].sum().plot(figsize=(12,5))
plt.show()

# %%
df.groupby("month")["units_sold"].mean().plot(kind="bar")
plt.show()

# %%
sns.barplot(x="is_weekend", y="units_sold", data=df)
plt.show()

# %%
sns.histplot(df["conversion_rate"], kde=True)
plt.show()

# %%
sns.histplot(df["inventory_pressure"], kde=True)
plt.show()

# %%
sns.histplot(df["competitor_gap"], kde=True)
plt.show()

# %%
sns.histplot(df["demand_ratio"], kde=True)
plt.show()

# %%
#key insights
High price reduces demand
Discounts increase sales
Certain categories perform better
Weekend sales may be higher
Competitor pricing affects demand
